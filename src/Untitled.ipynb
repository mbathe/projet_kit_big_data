# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
raw_interactions  =pd.read_csv(r"D:\Cours\BGDIA700\tp_bgdia700\data\dataset\RAW_interactions.csv")
pp_users = pd.read_csv(r"D:\Cours\BGDIA700\tp_bgdia700\data\dataset\PP_users.csv")

# %%
raw_interactions.dtypes
# Out:
# user_id       int64
# recipe_id     int64
# date         object
# rating        int64
# review       object
# dtype: object

# %%
#Pourcentage de valeur nuelle 
nombre_valeurs_nulles = (raw_interactions.isna().count().count())/(raw_interactions.shape[0]*raw_interactions.shape[1])
print(f"Pourcentage de valeurs nulle :{nombre_valeurs_nulles}")
# Out:
# Pourcentage de valeurs nulle :8.831059188407999e-07

# %%
raw_interactions["date"] = pd.to_datetime(raw_interactions["date"])
raw_interactions["month"] = raw_interactions["date"].dt.month
raw_interactions["year"] = raw_interactions["date"].dt.year
raw_interactions["day"] = raw_interactions["date"].dt.day

# %%
raw_interactions.head()
# Out:
#    user_id  recipe_id       date  rating  \
# 0    38094      40893 2003-02-17       4
# 1  1293707      40893 2011-12-21       5
# 2     8937      44394 2002-12-01       4
# 3   126440      85009 2010-02-27       5
# 4    57222      85009 2011-10-01       5
#
#                                               review  mois  year  day  month
# 0  Great with a salad. Cooked on top of stove for...     2  2003   17      2
# 1  So simple, so delicious! Great for chilly fall...    12  2011   21     12
# 2  This worked very well and is EASY.  I used not...    12  2002    1     12
# 3  I made the Mexican topping and took it to bunk...     2  2010   27      2
# 4  Made the cheddar bacon topping, adding a sprin...    10  2011    1     10

# %%
sns.relplot(data=raw_interactions, x = "day", y = "rating",kind = "line")
plt.figure(figsize=(10,7))

# %%
# Visualisation du ratio de rating par jour 
plt.figure(figsize=(6,5))
plt.hist(raw_interactions["rating"], color="blue",bins=5)
plt.title("Repartition des score")
plt.xlabel("Score")
plt.ylabel("fréquence")
plt.show()

# %%
# Load an example dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(data=raw_interactions, x="rating", kde=True)
